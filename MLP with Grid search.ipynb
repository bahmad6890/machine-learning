# %% [markdown]
# # Multi-layer Perceptron
#
# <ol>
#     <li> Components: Input layer, Hidden layer(s) and Output layer. </li>
#     <li> Fully connected </li>
# </ol>

# %% [markdown]
# ### Steps:
#
# For every epoch,
#
# <ol>
#     <li> Training data is propagated to the MLP through input layers. It passes through the hidden layers, if any forwarding outputs of activation functions to the next layer. Finally the output is generated at the output layer by applying activation functions. </li>
#     <li> The predicted output will be compared with actual output and hence error will be calculated. </li>
#     <li> If error>0, apply backpropagation methodology to modify weights starting from output layer moving towards input layer. </li>
#     <li> Check accuracy score. If satisfied, stop. Else, go to step 1. </li>
# </ol>

# %% [markdown]
# ### Import dataset

# %%
import pandas as pd
import numpy as np

dataset= pd.read_csv("allfaultdatasetfiltered5.csv")
#dataset= pd.read_csv("allfaultdatasetfiltered3.csv")
print(dataset.head())
print(dataset['class'].unique())
# Out:
#       speed  vibration  class
# 0  0.036017   0.019833      1
# 1  0.036346   0.026410      1
# 2  0.036346   0.033316      1
# 3  0.025825   0.034960      1
# 4  4.093751   0.029041      1
# [1 2 4]

# %%
dataset.shape
# Out:
# (59844, 3)

# %%
dataset.tail
# Out:
# <bound method NDFrame.tail of           speed  vibration  class
# 0      0.036017   0.019833      1
# 1      0.036346   0.026410      1
# 2      0.036346   0.033316      1
# 3      0.025825   0.034960      1
# 4      4.093751   0.029041      1
# ...         ...        ...    ...
# 59839  4.223946   0.016874      4
# 59840  0.040620   0.015887      4
# 59841  0.038976   0.016216      4
# 59842  0.039305   0.014901      4
# 59843  0.038976   0.015887      4
#
# [59844 rows x 3 columns]>

# %%
dataset.describe(include = 'all')
# Out:
#               speed     vibration         class
# count  59844.000000  59844.000000  59844.000000
# mean       2.104554      0.056508      2.331997
# std        2.052571      0.090963      1.247318
# min        0.013003     -0.324470      1.000000
# 25%        0.037661     -0.005817      1.000000
# 50%        2.021317      0.012928      2.000000
# 75%        4.197644      0.139534      4.000000
# max        4.318962      0.448979      4.000000

# %%
X = dataset['vibration']
y = dataset['class']
print(X.head(2))
print(y.head(2))
print(y.head())
# Out:
# 0   -0.002199
# 1   -0.001871
# Name: vibration, dtype: float64
# 0    0
# 1    0
# Name: class, dtype: int64
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
X = dataset['vibration'].values.reshape(-1, 1)
y = dataset['class'].values

# %% [markdown]
# ### Splitting to training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)
print(X_train.shape)
print(y_test.shape)
# Out:
# (41890, 1)
# (17954,)

# %% [markdown]
# Normalized input X train

# %% [markdown]
# ## Train the model
#
# Import the MLP classifier model from sklearn

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(solver='adam',max_iter=5000, activation='relu')
mlp
# Out:
# MLPClassifier(max_iter=5000)

# %% [markdown]
# ### About parameters
#
# 1. hidden_layer_sizes : tuple, length = n_layers - 2, default (100,)
#
# The ith element represents the number of neurons in the ith hidden layer.
#
# 2. activation : {‘identity’, ‘logistic’, ‘tanh’, ‘relu’}, default ‘relu’
#
# Activation function for the hidden layer.
#
# ‘identity’, no-op activation, useful to implement linear bottleneck, returns f(x) = x
# ‘logistic’, the logistic sigmoid function, returns f(x) = 1 / (1 + exp(-x)).
# ‘tanh’, the hyperbolic tan function, returns f(x) = tanh(x).
# ‘relu’, the rectified linear unit function, returns f(x) = max(0, x)
#
# 3. learning_rate : {‘constant’, ‘invscaling’, ‘adaptive’}, default ‘constant’
#
# 4. learning_rate_init : double, optional, default 0.001
#
# 5. max_iter : int, optional, default 200
#
# Maximum number of iterations. The solver iterates until convergence (determined by ‘tol’) or this number of iterations. For stochastic solvers (‘sgd’, ‘adam’), note that this determines the number of epochs (how many times each data point will be used), not the number of gradient steps.
#
# 6. shuffle : bool, optional, default True
#
# Whether to shuffle samples in each iteration. Only used when solver=’sgd’ or ‘adam’.
#
# 7. momentum : float, default 0.9
#
# Momentum for gradient descent update. Should be between 0 and 1. Only used when solver=’sgd’.
#
# 8. early_stopping : bool, default False
#
# Whether to use early stopping to terminate training when validation score is not improving. If set to true, it will automatically keep 10% of training data as validation and terminate training when validation score is not improving by at least tol for two consecutive epochs. Only effective when solver=’sgd’ or ‘adam’

# %% [markdown]
# ### Training

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(max_iter=5000)

# %% [markdown]
# ### Testing

# %%
pred = mlp.predict(X_test)
pred
# Out:
# array([1, 1, 4, ..., 2, 2, 1], dtype=int64)

# %% [markdown]
# ## Evaluation metrics- Confusion matrix and F2 score

# %%
from sklearn.metrics import classification_report,confusion_matrix

confusion_matrix(y_test,pred)
# Out:
# array([[4834,    0, 1177],
#        [  72, 5607,  297],
#        [3128,  171, 2668]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.60      0.80      0.69      6011
#            2       0.97      0.94      0.95      5976
#            4       0.64      0.45      0.53      5967
#
#     accuracy                           0.73     17954
#    macro avg       0.74      0.73      0.72     17954
# weighted avg       0.74      0.73      0.72     17954

# %%
# another approach 

from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(max_iter=100)

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html
#https://datascience.stackexchange.com/questions/19768/how-to-implement-pythons-mlpclassifier-with-gridsearchcv
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50),(10,50,10), (100,)],
    'activation': ['identity','tanh', 'relu', 'logistic'],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': [0.0001, 0.0002 , 0.0004 ,0.0009,0.002 ,0.006 , 0.01 , 0.05 ],
    'learning_rate': ['invscaling','constant','adaptive'],
    #'max_iterint': [100],
}

#{'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=5,verbose=4)
clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 581 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 850 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 1169 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 1536 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 1953 tasks      | elapsed: 32.0min
# [Parallel(n_jobs=-1)]: Done 2418 tasks      | elapsed: 47.5min
# [Parallel(n_jobs=-1)]: Done 2933 tasks      | elapsed: 63.5min
# [Parallel(n_jobs=-1)]: Done 3496 tasks      | elapsed: 83.4min
# [Parallel(n_jobs=-1)]: Done 4109 tasks      | elapsed: 105.1min
# [Parallel(n_jobs=-1)]: Done 4770 tasks      | elapsed: 120.1min
# [Parallel(n_jobs=-1)]: Done 5481 tasks      | elapsed: 131.8min
# [Parallel(n_jobs=-1)]: Done 5760 out of 5760 | elapsed: 136.6min finished
# GridSearchCV(cv=5, estimator=MLPClassifier(max_iter=100), n_jobs=-1,
#              param_grid={'activation': ['identity', 'tanh', 'relu', 'logistic'],
#                          'alpha': [0.0001, 0.0002, 0.0004, 0.0009, 0.002, 0.006,
#                                    0.01, 0.05],
#                          'hidden_layer_sizes': [(50, 50, 50), (50, 100, 50),
#                                                 (10, 50, 10), (100,)],
#                          'learning_rate': ['invscaling', 'constant',
#                                            'adaptive'],
#                          'solver': ['sgd', 'adam', 'lbfgs']},
#              verbose=4)

# %%
# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.637 (+/-0.037) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.658 (+/-0.065) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.657 (+/-0.041) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.647 (+/-0.064) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.663 (+/-0.054) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.650 (+/-0.048) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.653 (+/-0.073) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.659 (+/-0.062) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.657 (+/-0.068) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.656 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.656 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.679 (+/-0.016) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.516 (+/-0.324) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.651 (+/-0.071) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.658 (+/-0.028) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.648 (+/-0.057) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.655 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.624 (+/-0.041) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.439 (+/-0.421) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.681 (+/-0.028) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.669 (+/-0.046) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.651 (+/-0.080) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.646 (+/-0.054) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.630 (+/-0.043) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.656 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.576 (+/-0.233) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.642 (+/-0.068) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.656 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.647 (+/-0.068) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.665 (+/-0.058) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.672 (+/-0.076) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.642 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.633 (+/-0.074) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.647 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.655 (+/-0.059) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.667 (+/-0.037) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.458 (+/-0.439) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.674 (+/-0.037) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.651 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.654 (+/-0.056) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.656 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.655 (+/-0.010) for {'activation': 'identity', 'alpha': 0.
for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.704 (+/-0.013) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.731 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.701 (+/-0.031) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.731 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.562 (+/-0.243) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.730 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.720 (+/-0.019) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.732 (+/-0.008) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.722 (+/-0.020) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.730 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.595 (+/-0.128) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.636 (+/-0.053) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.663 (+/-0.011) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.619 (+/-0.059) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.665 (+/-0.022) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.660 (+/-0.071) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.641 (+/-0.026) for {'activation': 'tanh', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.730 (+/-0.010) for {'activation': 'tanh', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'tanh', 'alpha': 0.0002, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# ...
# 0.651 (+/-0.055) for {'activation': 'logistic', 'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.002, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.729 (+/-0.006) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.731 (+/-0.007) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.731 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.730 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.730 (+/-0.007) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.731 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.732 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.732 (+/-0.006) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.732 (+/-0.006) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.626 (+/-0.059) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.646 (+/-0.012) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.644 (+/-0.060) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.634 (+/-0.024) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.640 (+/-0.066) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.006, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.731 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.729 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.731 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.729 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.730 (+/-0.009) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.729 (+/-0.011) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.731 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.729 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.732 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.336 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.659 (+/-0.076) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.645 (+/-0.018) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.617 (+/-0.050) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.644 (+/-0.051) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.659 (+/-0.016) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.569 (+/-0.386) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.571 (+/-0.388) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.412 (+/-0.316) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.651 (+/-0.317) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.646 (+/-0.313) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.725 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.333 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.651 (+/-0.318) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.333 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.730 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.334 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.571 (+/-0.388) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.334 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.338 (+/-0.020) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.636 (+/-0.040) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.639 (+/-0.015) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.659 (+/-0.053) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.643 (+/-0.017) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.637 (+/-0.066) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# nan (+/-nan) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}

# %%
y_true, y_pred = y_test , clf.predict(X_test)

from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#            1       0.60      0.83      0.70      6011
#            2       0.97      0.94      0.95      5976
#            4       0.66      0.43      0.52      5967
#
#     accuracy                           0.73     17954
#    macro avg       0.74      0.73      0.72     17954
# weighted avg       0.74      0.73      0.72     17954

# %%
predicted_values = clf.predict(X_test)

from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,predicted_values)

print(score)
# Out:
# 0.731146262671271

# %% [markdown]
# ### Retesting :
#
# Retest the parameter obtained from grid search with diffrent iteration,

# %%
#retest best parameter from grid search with diffrent iteration 
#{'activation': 'relu', 'alpha': 0.006, 'hidden_layer_sizes': (10, 50, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
mlp = MLPClassifier(solver='adam',learning_rate = 'adaptive',alpha = 0.006, max_iter=5000, activation='relu')
mlp
# Out:
# MLPClassifier(alpha=0.006, learning_rate='adaptive', max_iter=5000)

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(alpha=0.006, learning_rate='adaptive', max_iter=5000)

# %%
pred = mlp.predict(X_test)
pred
# Out:
# array([1, 1, 4, ..., 2, 2, 1], dtype=int64)

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[4997,    0, 1014],
#        [  80, 5614,  282],
#        [3284,  181, 2502]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.60      0.83      0.70      6011
#            2       0.97      0.94      0.95      5976
#            4       0.66      0.42      0.51      5967
#
#     accuracy                           0.73     17954
#    macro avg       0.74      0.73      0.72     17954
# weighted avg       0.74      0.73      0.72     17954
